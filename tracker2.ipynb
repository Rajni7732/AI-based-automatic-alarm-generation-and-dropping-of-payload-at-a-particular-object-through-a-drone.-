# %%
# Install necessary packages
# !pip install ultralytics
# !pip install cvzone

# Import necessary libraries
import cv2
import pandas as pd
import numpy as np
from ultralytics import YOLO
from tracker import *
import cvzone

# Load the YOLO model
model = YOLO('yolov8s.pt')

# Define the RGB function for mouse event
def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

# Set up the window and mouse callback
cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

# Capture video
cap = cv2.VideoCapture('flood.mp4')

# Read class names from file
my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

# Initialize variables
count = 0
tracker = Tracker()

# Process video frames
while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    frame = cv2.resize(frame, (1020, 500))

    # Predict with YOLO model
    results = model.predict(frame)

    # Access bounding boxes, confidence scores, and class labels
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()  # Bounding boxes
        confs = result.boxes.conf.cpu().numpy()  # Confidence scores
        clss = result.boxes.cls.cpu().numpy()  # Class labels

        for box, conf, cls in zip(boxes, confs, clss):
            x1, y1, x2, y2 = map(int, box)
            c = class_list[int(cls)]
            if 'person' in c:
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 1)
                cv2.putText(frame, str(c), (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 255, 255), 1)

    # Show frame
    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release resources
cap.release()
cv
# Out:
# Requirement already satisfied: ultralytics in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (8.2.27)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.12.1)
# Requirement already satisfied: sympy in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: cvzone in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: opencv-python in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from cvzone) (4.9.0.80)
# Requirement already satisfied: numpy in /Users/rajni7731/anaconda3/lib/python3.11/site-packages (from cvzone) (1.24.3)
#
# 0: 320x640 4 boats, 109.2ms
# Speed: 1.7ms preprocess, 109.2ms inference, 380.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 104.7ms
# Speed: 0.9ms preprocess, 104.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [870, 475]
#
# 0: 320x640 4 boats, 104.9ms
# Speed: 0.9ms preprocess, 104.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 104.3ms
# Speed: 0.9ms preprocess, 104.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 114.5ms
# Speed: 1.2ms preprocess, 114.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 112.6ms
# Speed: 1.1ms preprocess, 112.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 111.2ms
# Speed: 1.3ms preprocess, 111.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 107.6ms
# Speed: 1.1ms preprocess, 107.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 106.9ms
# Speed: 0.9ms preprocess, 106.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 108.8ms
# Speed: 1.1ms preprocess, 108.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 108.3ms
# Speed: 1.1ms preprocess, 108.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 121.3ms
# Speed: 1.4ms preprocess, 121.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 132.3ms
# Speed: 1.0ms preprocess, 132.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 131.6ms
# Speed: 1.3ms preprocess, 131.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 118.4ms
# Speed: 1.0ms preprocess, 118.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 109.4ms
# Speed: 1.1ms preprocess, 109.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 104.9ms
# Speed: 0.9ms preprocess, 104.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 110.4ms
# Speed: 1.0ms preprocess, 110.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 1 boat, 108.2ms
# Speed: 1.2ms preprocess, 108.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 108.7ms
# Speed: 1.1ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.9ms
# Speed: 1.0ms preprocess, 108.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# [450, 191]
#
# 0: 320x640 2 boats, 111.7ms
# Speed: 1.4ms preprocess, 111.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [370, 32]
#
# 0: 320x640 1 boat, 112.2ms
# Speed: 1.2ms preprocess, 112.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.6ms
# Speed: 0.9ms preprocess, 108.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.0ms
# Speed: 1.4ms preprocess, 110.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.3ms
# Speed: 0.9ms preprocess, 111.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 112.5ms
# Speed: 1.1ms preprocess, 112.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 108.8ms
# Speed: 1.0ms preprocess, 108.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 113.0ms
# Speed: 1.1ms preprocess, 113.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.7ms
# Speed: 0.9ms preprocess, 111.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.8ms
# Speed: 0.9ms preprocess, 108.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.8ms
# Speed: 0.9ms preprocess, 108.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.9ms
# Speed: 1.0ms preprocess, 106.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.7ms
# Speed: 1.1ms preprocess, 110.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.3ms
# Speed: 1.1ms preprocess, 110.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.6ms
# Speed: 1.1ms preprocess, 106.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.4ms
# Speed: 1.6ms preprocess, 110.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.8ms
# Speed: 1.2ms preprocess, 108.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.3ms
# Speed: 1.2ms preprocess, 108.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.5ms
# Speed: 1.4ms preprocess, 106.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.7ms
# Speed: 0.9ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.5ms
# Speed: 1.1ms preprocess, 108.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.8ms
# Speed: 1.4ms preprocess, 109.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.4ms
# Speed: 0.9ms preprocess, 108.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.0ms
# Speed: 1.1ms preprocess, 110.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.3ms
# Speed: 1.2ms preprocess, 109.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.7ms
# Speed: 1.1ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.7ms
# Speed: 1.1ms preprocess, 109.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.6ms
# Speed: 1.4ms preprocess, 108.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.0ms
# Speed: 1.4ms preprocess, 108.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 109.4ms
# Speed: 1.2ms preprocess, 109.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 109.5ms
# Speed: 1.0ms preprocess, 109.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.9ms
# Speed: 1.0ms preprocess, 107.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 108.8ms
# Speed: 1.4ms preprocess, 108.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 106.8ms
# Speed: 0.9ms preprocess, 106.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.9ms
# Speed: 1.1ms preprocess, 108.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.0ms
# Speed: 1.4ms preprocess, 109.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.7ms
# Speed: 0.9ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.5ms
# Speed: 0.9ms preprocess, 107.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.9ms
# Speed: 0.9ms preprocess, 107.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.7ms
# Speed: 1.1ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.0ms
# Speed: 0.9ms preprocess, 107.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 106.6ms
# Speed: 0.9ms preprocess, 106.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.5ms
# Speed: 0.9ms preprocess, 106.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.5ms
# Speed: 1.4ms preprocess, 108.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.7ms
# Speed: 1.0ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 108.1ms
# Speed: 1.1ms preprocess, 108.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 frisbee, 108.2ms
# Speed: 0.9ms preprocess, 108.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 108.6ms
# Speed: 1.4ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 109.9ms
# Speed: 1.2ms preprocess, 109.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.7ms
# Speed: 0.9ms preprocess, 107.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.1ms
# Speed: 0.9ms preprocess, 106.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 105.9ms
# Speed: 1.0ms preprocess, 105.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 107.8ms
# Speed: 0.9ms preprocess, 107.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.3ms
# Speed: 1.1ms preprocess, 108.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 106.4ms
# Speed: 1.1ms preprocess, 106.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 108.5ms
# Speed: 1.4ms preprocess, 108.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 skateboard, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.0ms
# Speed: 1.2ms preprocess, 111.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 110.3ms
# Speed: 1.1ms preprocess, 110.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.2ms
# Speed: 1.2ms preprocess, 109.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.4ms
# Speed: 1.3ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.6ms
# Speed: 1.0ms preprocess, 108.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.0ms
# Speed: 0.9ms preprocess, 110.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.3ms
# Speed: 1.4ms preprocess, 109.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.2ms
# Speed: 1.2ms preprocess, 109.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.0ms
# Speed: 1.1ms preprocess, 109.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.8ms
# Speed: 1.1ms preprocess, 108.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.8ms
# Speed: 1.1ms preprocess, 110.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 106.2ms
# Speed: 1.0ms preprocess, 106.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.9ms
# Speed: 0.9ms preprocess, 108.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 umbrella, 106.1ms
# Speed: 1.0ms preprocess, 106.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 umbrella, 106.6ms
# Speed: 1.0ms preprocess, 106.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 umbrella, 107.3ms
# Speed: 0.9ms preprocess, 107.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 umbrella, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.7ms
# Speed: 1.1ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.7ms
# Speed: 1.1ms preprocess, 107.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.8ms
# Speed: 1.1ms preprocess, 107.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.9ms
# Speed: 1.0ms preprocess, 108.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 109.1ms
# Speed: 1.1ms preprocess, 109.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 108.7ms
# Speed: 1.3ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 frisbee, 106.2ms
# Speed: 0.9ms preprocess, 106.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 108.7ms
# Speed: 1.0ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 107.9ms
# Speed: 1.1ms preprocess, 107.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.3ms
# Speed: 0.9ms preprocess, 109.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.2ms
# Speed: 1.0ms preprocess, 106.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 109.6ms
# Speed: 1.2ms preprocess, 109.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 frisbee, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 frisbee, 108.5ms
# Speed: 1.2ms preprocess, 108.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.7ms
# Speed: 0.9ms preprocess, 107.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.4ms
# Speed: 1.2ms preprocess, 110.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.1ms
# Speed: 1.1ms preprocess, 109.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 train, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.9ms
# Speed: 0.9ms preprocess, 106.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 105.7ms
# Speed: 0.9ms preprocess, 105.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.9ms
# Speed: 1.4ms preprocess, 108.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 train, 108.3ms
# Speed: 1.0ms preprocess, 108.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 train, 108.8ms
# Speed: 1.4ms preprocess, 108.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 109.2ms
# Speed: 1.0ms preprocess, 109.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 106.2ms
# Speed: 1.0ms preprocess, 106.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 107.5ms
# Speed: 1.2ms preprocess, 107.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.6ms
# Speed: 1.1ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 106.8ms
# Speed: 0.9ms preprocess, 106.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 109.0ms
# Speed: 1.4ms preprocess, 109.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.6ms
# Speed: 1.0ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 107.3ms
# Speed: 0.9ms preprocess, 107.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 106.3ms
# Speed: 1.0ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 train, 105.4ms
# Speed: 0.9ms preprocess, 105.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 train, 106.3ms
# Speed: 0.9ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 boats, 107.5ms
# Speed: 1.1ms preprocess, 107.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 boat, 1 horse, 107.7ms
# Speed: 1.3ms preprocess, 107.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 horse, 105.6ms
# Speed: 0.9ms preprocess, 105.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 108.7ms
# Speed: 1.4ms preprocess, 108.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 2 boats, 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 9 cars, 2 boats, 109.7ms
# Speed: 1.1ms preprocess, 109.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 8 cars, 1 boat, 110.1ms
# Speed: 1.5ms preprocess, 110.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 1 boat, 108.6ms
# Speed: 1.1ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 9 cars, 1 boat, 108.7ms
# Speed: 1.1ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 106.1ms
# Speed: 1.4ms preprocess, 106.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 107.5ms
# Speed: 1.4ms preprocess, 107.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 1 boat, 106.7ms
# Speed: 0.9ms preprocess, 106.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 boats, 108.6ms
# Speed: 1.4ms preprocess, 108.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 3 cars, 2 boats, 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 5 cars, 1 boat, 109.4ms
# Speed: 1.2ms preprocess, 109.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 5 cars, 1 boat, 109.4ms
# Speed: 1.0ms preprocess, 109.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 6 cars, 1 boat, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 2 cars, 109.2ms
# Speed: 1.0ms preprocess, 109.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 107.0ms
# Speed: 1.0ms preprocess, 107.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 1 truck, 109.5ms
# Speed: 1.0ms preprocess, 109.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 1 boat, 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 1 truck, 1 boat, 106.8ms
# Speed: 1.0ms preprocess, 106.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 3 cars, 1 boat, 106.5ms
# Speed: 0.9ms preprocess, 106.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 6 cars, 1 boat, 106.2ms
# Speed: 0.9ms preprocess, 106.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 persons, 5 cars, 1 boat, 106.4ms
# Speed: 1.1ms preprocess, 106.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 6 cars, 1 boat, 109.6ms
# Speed: 1.0ms preprocess, 109.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 persons, 5 cars, 2 boats, 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 persons, 4 cars, 2 boats, 110.1ms
# Speed: 1.2ms preprocess, 110.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 1 boat, 108.3ms
# Speed: 1.2ms preprocess, 108.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 1 boat, 106.0ms
# Speed: 0.9ms preprocess, 106.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 boat, 108.6ms
# Speed: 1.5ms preprocess, 108.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 boats, 108.1ms
# Speed: 1.2ms preprocess, 108.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 2 cars, 2 boats, 108.8ms
# Speed: 1.2ms preprocess, 108.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 persons, 2 cars, 2 boats, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 1 boat, 108.0ms
# Speed: 0.9ms preprocess, 108.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 2 cars, 1 boat, 109.1ms
# Speed: 1.0ms preprocess, 109.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 4 cars, 3 boats, 106.7ms
# Speed: 1.1ms preprocess, 106.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 1 boat, 106.3ms
# Speed: 1.0ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 1 boat, 106.9ms
# Speed: 0.9ms preprocess, 106.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 1 boat, 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 1 car, 1 boat, 106.3ms
# Speed: 0.9ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 1 car, 1 boat, 109.6ms
# Speed: 1.4ms preprocess, 109.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 1 car, 1 boat, 109.9ms
# Speed: 1.2ms preprocess, 109.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 1 boat, 108.2ms
# Speed: 0.9ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 boats, 110.7ms
# Speed: 1.4ms preprocess, 110.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 boats, 109.8ms
# Speed: 1.1ms preprocess, 109.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 boats, 107.0ms
# Speed: 0.9ms preprocess, 107.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 boat, 109.1ms
# Speed: 1.0ms preprocess, 109.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 boats, 108.5ms
# Speed: 1.2ms preprocess, 108.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 boats, 108.5ms
# Speed: 1.2ms preprocess, 108.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 boat, 107.3ms
# Speed: 0.9ms preprocess, 107.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 boats, 106.7ms
# Speed: 1.1ms preprocess, 106.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 boat, 108.6ms
# Speed: 1.1ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 4 boats, 109.9ms
# Speed: 1.2ms preprocess, 109.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 1 car, 2 boats, 108.9ms
# Speed: 1.1ms preprocess, 108.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 4 boats, 109.8ms
# Speed: 1.0ms preprocess, 109.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 3 boats, 106.4ms
# Speed: 1.0ms preprocess, 106.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 4 boats, 107.3ms
# Speed: 0.9ms preprocess, 107.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 108.6ms
# Speed: 1.4ms preprocess, 108.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 106.3ms
# Speed: 0.9ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 boats, 106.5ms
# Speed: 0.9ms preprocess, 106.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 boats, 109.6ms
# Speed: 1.2ms preprocess, 109.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 boats, 109.5ms
# Speed: 1.2ms preprocess, 109.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 boats, 109.7ms
# Speed: 1.2ms preprocess, 109.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 boats, 106.9ms
# Speed: 0.9ms preprocess, 106.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 boats, 107.5ms
# Speed: 0.9ms preprocess, 107.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 109.4ms
# Speed: 1.1ms preprocess, 109.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 1 surfboard, 108.4ms
# Speed: 1.0ms preprocess, 108.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 1 surfboard, 108.8ms
# Speed: 1.2ms preprocess, 108.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 1 surfboard, 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 boats, 1 surfboard, 108.9ms
# Speed: 1.0ms preprocess, 108.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 boats, 107.4ms
# Speed: 1.0ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 boats, 1 surfboard, 108.7ms
# Speed: 1.1ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 boats, 110.2ms
# Speed: 1.5ms preprocess, 110.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 boat, 1 surfboard, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 boats, 1 surfboard, 109.7ms
# Speed: 1.1ms preprocess, 109.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.2ms
# Speed: 0.9ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.0ms
# Speed: 0.9ms preprocess, 106.0ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 1 sports ball, 106.0ms
# Speed: 1.0ms preprocess, 106.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [591, 476]
#
# 0: 320x640 1 sports ball, 109.2ms
# Speed: 1.1ms preprocess, 109.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 1 sports ball, 107.4ms
# Speed: 1.0ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 frisbee, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.9ms
# Speed: 1.1ms preprocess, 109.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.1ms
# Speed: 1.0ms preprocess, 109.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.2ms
# Speed: 1.1ms preprocess, 107.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.6ms
# Speed: 0.9ms preprocess, 107.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.0ms
# Speed: 0.9ms preprocess, 106.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.4ms
# Speed: 1.1ms preprocess, 106.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 105.7ms
# Speed: 1.0ms preprocess, 105.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 104.8ms
# Speed: 0.9ms preprocess, 104.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 105.5ms
# Speed: 0.9ms preprocess, 105.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 104.5ms
# Speed: 0.9ms preprocess, 104.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.5ms
# Speed: 0.9ms preprocess, 106.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 104.8ms
# Speed: 0.9ms preprocess, 104.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.5ms
# Speed: 1.1ms preprocess, 108.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.1ms
# Speed: 1.0ms preprocess, 106.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# [569, 476]
#
# 0: 320x640 (no detections), 106.1ms
# Speed: 0.9ms preprocess, 106.1ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 640)
# [146, 150]
#
# 0: 320x640 (no detections), 109.6ms
# Speed: 1.3ms preprocess, 109.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# [66, 17]
#
# 0: 320x640 (no detections), 109.3ms
# Speed: 1.2ms preprocess, 109.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# [88, 8]
#
# 0: 320x640 1 car, 106.6ms
# Speed: 0.9ms preprocess, 106.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 106.6ms
# Speed: 0.9ms preprocess, 106.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 107.9ms
# Speed: 1.1ms preprocess, 107.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 109.9ms
# Speed: 1.5ms preprocess, 109.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [196, 142]
#
# 0: 320x640 1 car, 107.7ms
# Speed: 0.9ms preprocess, 107.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# [299, 222]
#
# 0: 320x640 2 persons, 1 car, 110.7ms
# Speed: 1.1ms preprocess, 110.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [320, 237]
#
# 0: 320x640 (no detections), 109.7ms
# Speed: 1.2ms preprocess, 109.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.5ms
# Speed: 1.0ms preprocess, 109.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.0ms
# Speed: 1.1ms preprocess, 111.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 110.5ms
# Speed: 1.2ms preprocess, 110.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 108.5ms
# Speed: 0.9ms preprocess, 108.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 108.5ms
# Speed: 1.1ms preprocess, 108.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 106.1ms
# Speed: 0.9ms preprocess, 106.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 1 car, 106.3ms
# Speed: 1.1ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 105.1ms
# Speed: 0.9ms preprocess, 105.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 108.1ms
# Speed: 1.1ms preprocess, 108.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 114.2ms
# Speed: 0.9ms preprocess, 114.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.3ms
# Speed: 1.1ms preprocess, 111.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 114.2ms
# Speed: 1.1ms preprocess, 114.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 109.7ms
# Speed: 0.9ms preprocess, 109.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 113.0ms
# Speed: 1.1ms preprocess, 113.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 110.0ms
# Speed: 1.1ms preprocess, 110.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 114.9ms
# Speed: 1.5ms preprocess, 114.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 113.5ms
# Speed: 1.2ms preprocess, 113.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 113.7ms
# Speed: 1.2ms preprocess, 113.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 120.5ms
# Speed: 0.9ms preprocess, 120.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 107.2ms
# Speed: 0.9ms preprocess, 107.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 116.4ms
# Speed: 1.5ms preprocess, 116.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 117.5ms
# Speed: 1.1ms preprocess, 117.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 112.2ms
# Speed: 0.9ms preprocess, 112.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.3ms
# Speed: 1.1ms preprocess, 115.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 122.9ms
# Speed: 1.5ms preprocess, 122.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.3ms
# Speed: 1.6ms preprocess, 115.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 106.8ms
# Speed: 1.1ms preprocess, 106.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 train, 108.0ms
# Speed: 0.9ms preprocess, 108.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 114.5ms
# Speed: 1.1ms preprocess, 114.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 116.8ms
# Speed: 1.1ms preprocess, 116.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 donut, 113.9ms
# Speed: 0.9ms preprocess, 113.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 1 donut, 116.8ms
# Speed: 1.1ms preprocess, 116.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.1ms
# Speed: 0.9ms preprocess, 112.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.8ms
# Speed: 1.1ms preprocess, 112.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.6ms
# Speed: 1.0ms preprocess, 110.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 115.8ms
# Speed: 1.5ms preprocess, 115.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 117.4ms
# Speed: 1.2ms preprocess, 117.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 114.8ms
# Speed: 1.2ms preprocess, 114.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 113.3ms
# Speed: 1.3ms preprocess, 113.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 120.0ms
# Speed: 1.2ms preprocess, 120.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.7ms
# Speed: 1.0ms preprocess, 112.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 boats, 112.5ms
# Speed: 1.1ms preprocess, 112.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.4ms
# Speed: 0.9ms preprocess, 112.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 112.3ms
# Speed: 0.9ms preprocess, 112.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 116.7ms
# Speed: 1.1ms preprocess, 116.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 114.4ms
# Speed: 0.9ms preprocess, 114.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 114.8ms
# Speed: 1.2ms preprocess, 114.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 114.8ms
# Speed: 1.1ms preprocess, 114.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 113.9ms
# Speed: 1.0ms preprocess, 113.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 116.2ms
# Speed: 1.5ms preprocess, 116.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 116.2ms
# Speed: 1.5ms preprocess, 116.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.1ms
# Speed: 1.1ms preprocess, 112.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 119.9ms
# Speed: 1.4ms preprocess, 119.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 donut, 113.0ms
# Speed: 1.1ms preprocess, 113.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 donut, 112.9ms
# Speed: 1.0ms preprocess, 112.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 donut, 118.3ms
# Speed: 1.0ms preprocess, 118.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 donut, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 donut, 111.0ms
# Speed: 1.2ms preprocess, 111.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 donut, 108.5ms
# Speed: 0.9ms preprocess, 108.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [423, 291]
#
# 0: 320x640 1 boat, 113.2ms
# Speed: 1.6ms preprocess, 113.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [218, 248]
#
# 0: 320x640 1 boat, 112.8ms
# Speed: 1.3ms preprocess, 112.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 donut, 107.7ms
# Speed: 0.9ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 2 donuts, 111.4ms
# Speed: 1.5ms preprocess, 111.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.4ms
# Speed: 1.0ms preprocess, 111.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [32, 2]
#
# 0: 320x640 1 boat, 110.8ms
# Speed: 1.3ms preprocess, 110.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [132, 106]
#
# 0: 320x640 1 boat, 111.8ms
# Speed: 1.2ms preprocess, 111.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [237, 224]
#
# 0: 320x640 1 boat, 1 donut, 108.2ms
# Speed: 1.0ms preprocess, 108.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 donut, 111.4ms
# Speed: 1.1ms preprocess, 111.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 donut, 110.9ms
# Speed: 1.1ms preprocess, 110.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 110.1ms
# Speed: 1.2ms preprocess, 110.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.4ms
# Speed: 1.5ms preprocess, 111.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.1ms
# Speed: 1.0ms preprocess, 110.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.2ms
# Speed: 1.1ms preprocess, 110.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.3ms
# Speed: 1.3ms preprocess, 110.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.7ms
# Speed: 1.0ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.1ms
# Speed: 1.1ms preprocess, 111.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [237, 224]
#
# 0: 320x640 1 boat, 111.2ms
# Speed: 1.1ms preprocess, 111.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# [461, 419]
#
# 0: 320x640 1 boat, 106.9ms
# Speed: 0.9ms preprocess, 106.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.2ms
# Speed: 1.0ms preprocess, 110.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 109.2ms
# Speed: 1.1ms preprocess, 109.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 108.4ms
# Speed: 0.9ms preprocess, 108.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 108.7ms
# Speed: 1.0ms preprocess, 108.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.7ms
# Speed: 1.1ms preprocess, 110.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.3ms
# Speed: 1.1ms preprocess, 111.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.4ms
# Speed: 1.0ms preprocess, 109.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 111.1ms
# Speed: 1.2ms preprocess, 111.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 109.3ms
# Speed: 1.0ms preprocess, 109.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.1ms
# Speed: 1.4ms preprocess, 110.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 107.5ms
# Speed: 0.9ms preprocess, 107.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 110.7ms
# Speed: 1.4ms preprocess, 110.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 boats, 117.5ms
# Speed: 0.9ms preprocess, 117.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 boat, 115.8ms
# Speed: 1.2ms preprocess, 115.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 112.4ms
# Speed: 1.0ms preprocess, 112.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 112.2ms
# Speed: 1.1ms preprocess, 112.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 118.8ms
# Speed: 1.5ms preprocess, 118.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 113.5ms
# Speed: 1.0ms preprocess, 113.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 115.4ms
# Speed: 1.8ms preprocess, 115.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 116.5ms
# Speed: 1.3ms preprocess, 116.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 121.9ms
# Speed: 1.2ms preprocess, 121.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 112.3ms
# Speed: 1.1ms preprocess, 112.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 108.1ms
# Speed: 0.9ms preprocess, 108.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 107.4ms
# Speed: 1.0ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 111.5ms
# Speed: 1.1ms preprocess, 111.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 112.8ms
# Speed: 1.1ms preprocess, 112.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 111.9ms
# Speed: 1.1ms preprocess, 111.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 114.9ms
# Speed: 1.2ms preprocess, 114.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 116.0ms
# Speed: 1.0ms preprocess, 116.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 110.0ms
# Speed: 1.2ms preprocess, 110.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 116.8ms
# Speed: 1.2ms preprocess, 116.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 112.4ms
# Speed: 1.0ms preprocess, 112.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 116.6ms
# Speed: 1.3ms preprocess, 116.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 boats, 1 chair, 113.7ms
# Speed: 1.1ms preprocess, 113.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 chair, 113.0ms
# Speed: 1.3ms preprocess, 113.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 chair, 111.4ms
# Speed: 1.2ms preprocess, 111.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 113.4ms
# Speed: 1.2ms preprocess, 113.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 1 chair, 111.4ms
# Speed: 1.2ms preprocess, 111.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 116.8ms
# Speed: 1.3ms preprocess, 116.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 116.2ms
# Speed: 1.2ms preprocess, 116.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 120.3ms
# Speed: 1.0ms preprocess, 120.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.7ms
# Speed: 1.1ms preprocess, 110.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 116.0ms
# Speed: 1.1ms preprocess, 116.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.5ms
# Speed: 1.1ms preprocess, 115.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 114.2ms
# Speed: 0.9ms preprocess, 114.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.5ms
# Speed: 0.9ms preprocess, 111.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.6ms
# Speed: 1.0ms preprocess, 109.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.6ms
# Speed: 1.1ms preprocess, 111.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.2ms
# Speed: 1.0ms preprocess, 111.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.0ms
# Speed: 0.9ms preprocess, 111.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 113.6ms
# Speed: 1.1ms preprocess, 113.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 113.1ms
# Speed: 1.2ms preprocess, 113.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 114.0ms
# Speed: 1.2ms preprocess, 114.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 113.3ms
# Speed: 1.2ms preprocess, 113.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 114.7ms
# Speed: 1.0ms preprocess, 114.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 112.8ms
# Speed: 1.1ms preprocess, 112.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 117.3ms
# Speed: 1.1ms preprocess, 117.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 112.6ms
# Speed: 1.1ms preprocess, 112.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 114.7ms
# Speed: 1.5ms preprocess, 114.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 109.6ms
# Speed: 1.0ms preprocess, 109.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 109.1ms
# Speed: 1.1ms preprocess, 109.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 113.3ms
# Speed: 1.1ms preprocess, 113.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 111.2ms
# Speed: 0.9ms preprocess, 111.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 113.6ms
# Speed: 1.1ms preprocess, 113.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.5ms
# Speed: 1.1ms preprocess, 115.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.0ms
# Speed: 1.1ms preprocess, 115.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 112.7ms
# Speed: 1.2ms preprocess, 112.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 115.4ms
# Speed: 1.1ms preprocess, 115.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 110.5ms
# Speed: 1.0ms preprocess, 110.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 109.4ms
# Speed: 0.9ms preprocess, 109.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 113.7ms
# Speed: 1.4ms preprocess, 113.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 114.3ms
# Speed: 1.0ms preprocess, 114.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 71
#      69 # Release resources
#      70 cap.release()
# ---> 71 cv
#
# NameError: name 'cv' is not defined
